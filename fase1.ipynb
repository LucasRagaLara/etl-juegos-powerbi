# %% [markdown]
# Cargar entorno y crear SparkSession

# %%
# !pip install howlongtobeatpy
# Out:
# Requirement already satisfied: howlongtobeatpy in /opt/conda/lib/python3.11/site-packages (1.0.18)
# Requirement already satisfied: aiohttp>=3.11.10 in /opt/conda/lib/python3.11/site-packages (from howlongtobeatpy) (3.12.0)
# Requirement already satisfied: requests>=2.32.3 in /opt/conda/lib/python3.11/site-packages (from howlongtobeatpy) (2.32.3)
# Requirement already satisfied: aiounittest>=1.4.2 in /opt/conda/lib/python3.11/site-packages (from howlongtobeatpy) (1.5.0)
# Requirement already satisfied: fake_useragent>=2.0.3 in /opt/conda/lib/python3.11/site-packages (from howlongtobeatpy) (2.2.0)
# Requirement already satisfied: beautifulsoup4>=4.12.3 in /opt/conda/lib/python3.11/site-packages (from howlongtobeatpy) (4.13.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp>=3.11.10->howlongtobeatpy) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.11/site-packages (from aiohttp>=3.11.10->howlongtobeatpy) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp>=3.11.10->howlongtobeatpy) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.11/site-packages (from aiohttp>=3.11.10->howlongtobeatpy) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.11/site-packages (from aiohttp>=3.11.10->howlongtobeatpy) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp>=3.11.10->howlongtobeatpy) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp>=3.11.10->howlongtobeatpy) (1.20.0)
# Requirement already satisfied: wrapt in /opt/conda/lib/python3.11/site-packages (from aiounittest>=1.4.2->howlongtobeatpy) (1.17.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.11/site-packages (from beautifulsoup4>=4.12.3->howlongtobeatpy) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/conda/lib/python3.11/site-packages (from beautifulsoup4>=4.12.3->howlongtobeatpy) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests>=2.32.3->howlongtobeatpy) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests>=2.32.3->howlongtobeatpy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests>=2.32.3->howlongtobeatpy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests>=2.32.3->howlongtobeatpy) (2023.7.22)

# %%
from datetime import datetime
from pyspark.sql import SparkSession
import os
from dotenv import load_dotenv
import pandas as pd
import requests
from collections import Counter

# Cargar variables de entorno
load_dotenv("/home/jovyan/work/.env")

# Variables
MYSQL_HOST = os.getenv("MYSQL_HOST")
MYSQL_PORT = os.getenv("MYSQL_PORT")
MYSQL_USER = os.getenv("MYSQL_USER")
MYSQL_PASSWORD = os.getenv("MYSQL_PASSWORD")
MYSQL_DATABASE = os.getenv("MYSQL_DATABASE")
TWITCH_CLIENT_ID = os.getenv("TWITCH_CLIENT_ID")
TWITCH_TOKEN = os.getenv("TWITCH_TOKEN")

# Crear sesión Spark con conector JDBC
spark = SparkSession.builder \
    .appName("Fase 1 - Videojuegos") \
    .config("spark.jars", "/home/jovyan/work/jars/mysql-connector-j-8.0.31.jar") \
    .getOrCreate()

# %% [markdown]
# **Función para insertar en log_carga (vía Spark)**

# %%
def insertar_log_mysql(origen, archivo, cantidad, inicio, fin):
    log_df = spark.createDataFrame([{
        "origen": origen,
        "archivo": archivo,
        "cantidad": int(cantidad),
        "fecha_inicio": inicio,
        "fecha_fin": fin
    }])

    log_df.write \
        .format("jdbc") \
        .option("url", f"jdbc:mysql://{MYSQL_HOST}:{MYSQL_PORT}/{MYSQL_DATABASE}") \
        .option("driver", "com.mysql.cj.jdbc.Driver") \
        .option("dbtable", "log_carga") \
        .option("user", MYSQL_USER) \
        .option("password", MYSQL_PASSWORD) \
        .mode("append") \
        .save()

# %% [markdown]
# **Renovar el token**

# %%
def obtener_token_twitch():
    client_id = os.getenv("TWITCH_CLIENT_ID")
    client_secret = os.getenv("TWITCH_CLIENT_SECRET")  # necesitas esta variable en tu .env

    response = requests.post("https://id.twitch.tv/oauth2/token", data={
        'client_id': client_id,
        'client_secret': client_secret,
        'grant_type': 'client_credentials'
    })

    if response.status_code == 200:
        token = response.json()['access_token']
        print("✅ Nuevo token obtenido:", token)
        return token
    else:
        print("❌ Error al obtener token:", response.status_code, response.text)
        return None

# Obtener y usar nuevo token
TWITCH_TOKEN = obtener_token_twitch()
headers = {
    'Client-ID': TWITCH_CLIENT_ID,
    'Authorization': f'Bearer {TWITCH_TOKEN}'
}
# Out:
# ✅ Nuevo token obtenido: k8c5xqwb0j23qh6oe4ta5uico7hh8w

# %% [markdown]
# **Descarga desde Twitch API**

# %%
# headers = {
#     'Client-ID': TWITCH_CLIENT_ID,
#     'Authorization': f'Bearer {TWITCH_TOKEN}'
# }
# inicio = datetime.now()
# response = requests.get("https://api.twitch.tv/helix/games/top?first=100", headers=headers)
# print("STATUS:", response.status_code)
# print("RESPONSE:", response.json())
# datos = response.json()["data"]
# df_twitch = pd.DataFrame(datos)
# df_twitch_spark = spark.createDataFrame(df_twitch)
# archivo_twitch = "twitch_top_games.parquet"
# df_twitch_spark.write.mode("overwrite").parquet(f"/home/jovyan/work/{archivo_twitch}")
# fin = datetime.now()
# insertar_log_mysql("Twitch", archivo_twitch, df_twitch.shape[0], inicio, fin)

# %%
import requests
import pandas as pd
from datetime import datetime
from collections import Counter
import json
import time

headers = {
    'Client-ID': TWITCH_CLIENT_ID,
    'Authorization': f'Bearer {TWITCH_TOKEN}'
}

# Paso 1: Extraer top juegos
inicio = datetime.now()
response = requests.get("https://api.twitch.tv/helix/games/top?first=100", headers=headers)
print("STATUS:", response.status_code)
datos = response.json()["data"]
df_twitch = pd.DataFrame(datos)

# Paso 2: Enriquecer con datos de streams
stream_data = []

for _, row in df_twitch.iterrows():
    game_id = row['id']

    for intento in range(3):  # Máximo 3 intentos
        try:
            stream_resp = requests.get(
                f"https://api.twitch.tv/helix/streams?game_id={game_id}",
                headers=headers,
                timeout=10
            )

            if stream_resp.status_code == 200:
                break
            else:
                print(f"Intento {intento+1} fallido con status {stream_resp.status_code} para game_id {game_id}")
                time.sleep(2)

        except requests.exceptions.SSLError as e:
            print(f"SSL error en game_id {game_id}, intento {intento+1}: {e}")
            time.sleep(2)
        except Exception as e:
            print(f"Error general en game_id {game_id}, intento {intento+1}: {e}")
            time.sleep(2)
    else:
        print(f"No se pudo procesar game_id {game_id} tras 3 intentos.")
        stream_data.append({
            "id": game_id,
            "total_viewers": None,
            "num_streams": None,
            "avg_viewers": None,
            "languages": None,
            "has_mature_stream": None
        })
        continue

    streams = stream_resp.json().get("data", [])
    total_viewers = sum(stream.get("viewer_count", 0) for stream in streams)
    num_streams = len(streams)
    avg_viewers = total_viewers / num_streams if num_streams > 0 else 0
    langs = Counter(stream.get("language", "unknown") for stream in streams)
    has_mature_stream = any(stream.get("is_mature", False) for stream in streams)

    stream_data.append({
        "id": game_id,
        "total_viewers": total_viewers,
        "num_streams": num_streams,
        "avg_viewers": avg_viewers,
        "languages": json.dumps(dict(langs)),
        "has_mature_stream": has_mature_stream
    })

    time.sleep(0.4)  # Control de velocidad para Twitch API

# Convertir a DataFrame y unir
df_streams = pd.DataFrame(stream_data)
df_twitch_enriched = pd.merge(df_twitch, df_streams, on="id", how="left")

df_twitch_enriched
# Out:
# STATUS: 200
# Error general en game_id 1494, intento 1: HTTPSConnectionPool(host='api.twitch.tv', port=443): Read timed out. (read timeout=10)
#             id                                                       name  \
# 0       509658                                              Just Chatting
# 1        32982                                         Grand Theft Auto V
# 2        29595                                                     Dota 2
# 3       491487                                           Dead by Daylight
# 4        21779                                          League of Legends
# 5        32399                                             Counter-Strike
# 6       509672                                                        IRL
# 7       516575                                                   VALORANT
# 8        33214                                                   Fortnite
# 9       512710                                      Call of Duty: Warzone
# 10  2011938005                                            EA Sports FC 25
# 11       18122                                          World of Warcraft
# 12       27471                                                  Minecraft
# 13      509663                                             Special Events
# 14      504463                                Tom Clancy's The Division 2
# 15      493057                                        PUBG: BATTLEGROUNDS
# 16  1264310518                                              Marvel Rivals
# 17  1115469318                                    Laundry Store Simulator
# 18      518186                                              Party Animals
# 19    93798731                                                      F1 25
# 20      511224                                               Apex Legends
# 21      515025                                                Overwatch 2
# 22    36799602                                Clair Obscur: Expedition 33
# 23         743                                                      Chess
# 24       24241                                   FINAL FANTASY XIV ONLINE
# 25      513143                                          Teamfight Tactics
# 26       27546                                             World of Tanks
# 27      492546                                   Star Wars Battlefront II
# 28      138585                                                Hearthstone
# 29      491931                                         Escape from Tarkov
# 30      509660                                                        Art
# 31      512953                                                 ELDEN RING
# 32  1669431183                                                        DJs
# 33      518203                                                     Sports
# 34       13389                                          Age of Empires II
# 35  1804231074                                          MapleStory Worlds
# 36   401587136                                   Arena Breakout: Infinite
# 37      263490                                                       Rust
# 38      460630                             Tom Clancy's Rainbow Six Siege
# 39      513181                                             Genshin Impact
# 40       29452                                             Virtual Casino
# 41      498566                                                      Slots
# 42      417752                                      Talk Shows & Podcasts
# 43       65632                                                       DayZ
# 44      493959                                      Red Dead Redemption 2
# 45  2058566581                               Mafia II: Definitive Edition
# 46   987413865                                      Deadly Days: Roadtrip
# 47      508455                                                    Valheim
# 48      497057                                                  Destiny 2
# 49  1106985046                                                  RoadCraft
# 50      490377                                             Sea of Thieves
# 51      508685                                                   SIGNALIS
# 52      515586                          Tainted Grail: The Fall of Avalon
# 53      459931                                       Old School RuneScape
# 54      488190                                                      Poker
# 55      509659                                                       ASMR
# 56       30921                                              Rocket League
# 57  1801167658                                      Drive Beyond Horizons
# 58  1756782008                                                    9 Kings
# 59   329951934                                     Pokémon Community Game
# 60      499973                                                  Always On
# 61       19619                                                      Tibia
# 62      417528                                              Albion Online
# 63    55453844                                           Street Fighter 6
# 64       12839  Heroes of Might and Magic III: The Restoration of Erathia
# 65  2106425216                                          Gray Zone Warfare
# 66       71375                                               Star Citizen
# 67  1307200028                                        Streamer University
# 68       26936                                                      Music
# 69      515024                                                  Diablo IV
# 70   687129551                                                 Trackmania
# 71      505705                                                      Noita
# 72      386821                                               Black Desert
# 73       27284                                                      Retro
# 74      491168                                               Clash Royale
# 75   409950050                                                  Torn Away
# 76  1282866981                                                Delta Force
# 77        1229                                          Super Mario World
# 78       23020                                                     ROBLOX
# 79   504371622                                            Monster Train 2
# 80  1672324422                                  Call of Duty: Black Ops 6
# 81   272263131                               Animals, Aquariums, and Zoos
# 82   569438345                            Quarantine Zone: The Last Check
# 83       13332                                  Pokémon FireRed/LeafGreen
# 84   670867987                                     Pokémon Scarlet/Violet
# 85      494184                                  Mobile Legends: Bang Bang
# 86   209738946                                            Wuthering Waves
# 87  2013539540                                                Blue Prince
# 88   538054672                                                   TEKKEN 8
# 89      512998                  The Legend of Zelda: Tears of the Kingdom
# 90  1549167076                                    S.T.A.L.K.E.R.: Anomaly
# 91  1294658629                                                   R.E.P.O.
# 92        2748                                       Magic: The Gathering
# 93  2068583461                                                   NBA 2K25
# 94  1023750977                                                   FragPunk
# 95        1041                                                  Diablo II
# 96        1494                                               Call of Duty
# 97      510389                                          Shakes and Fidget
# 98      499634                                                     Crypto
# 99       32502                                          World of Warships
#
#                                                                      box_art_url  \
# 0            https://static-cdn.jtvnw.net/ttv-boxart/509658-{width}x{height}.jpg
# 1        https://static-cdn.jtvnw.net/ttv-boxart/32982_IGDB-{width}x{height}.jpg
# 2             https://static-cdn.jtvnw.net/ttv-boxart/29595-{width}x{height}.jpg
# 3            https://static-cdn.jtvnw.net/ttv-boxart/491487-{width}x{height}.jpg
# 4             https://static-cdn.jtvnw.net/ttv-boxart/21779-{width}x{height}.jpg
# 5             https://static-cdn.jtvnw.net/ttv-boxart/32399-{width}x{height}.jpg
# 6            https://static-cdn.jtvnw.net/ttv-boxart/509672-{width}x{height}.jpg
# 7            https://static-cdn.jtvnw.net/ttv-boxart/516575-{width}x{height}.jpg
# 8             https://static-cdn.jtvnw.net/ttv-boxart/33214-{width}x{height}.jpg
# 9            https://static-cdn.jtvnw.net/ttv-boxart/512710-{width}x{height}.jpg
# 10  https://static-cdn.jtvnw.net/ttv-boxart/2011938005_IGDB-{width}x{height}.jpg
# 11            https://static-cdn.jtvnw.net/ttv-boxart/18122-{width}x{height}.jpg
# 12       https://static-cdn.jtvnw.net/ttv-boxart/27471_IGDB-{width}x{height}.jpg
# 13           https://static-cdn.jtvnw.net/ttv-boxart/509663-{width}x{height}.jpg
# 14      https://static-cdn.jtvnw.net/ttv-boxart/504463_IGDB-{width}x{height}.jpg
# 15           https://static-cdn.jtvnw.net/ttv-boxart/493057-{width}x{height}.jpg
# 16  https://static-cdn.jtvnw.net/ttv-boxart/1264310518_IGDB-{width}x{height}.jpg
# 17  https://static-cdn.jtvnw.net/ttv-boxart/1115469318_IGDB-{width}x{height}.jpg
# 18      https://static-cdn.jtvnw.net/ttv-boxart/518186_IGDB-{width}x{height}.jpg
# 19    https://static-cdn.jtvnw.net/ttv-boxart/93798731_IGDB-{width}x{height}.jpg
# 20           https://static-cdn.jtvnw.net/ttv-boxart/511224-{width}x{height}.jpg
# 21           https://static-cdn.jtvnw.net/ttv-boxart/515025-{width}x{height}.jpg
# 22    https://static-cdn.jtvnw.net/ttv-boxart/36799602_IGDB-{width}x{height}.jpg
# 23              https://static-cdn.jtvnw.net/ttv-boxart/743-{width}x{height}.jpg
# 24       https://static-cdn.jtvnw.net/ttv-boxart/24241_IGDB-{width}x{height}.jpg
# 25           https://static-cdn.jtvnw.net/ttv-boxart/513143-{width}x{height}.jpg
# 26            https://static-cdn.jtvnw.net/ttv-boxart/27546-{width}x{height}.jpg
# 27           https://static-cdn.jtvnw.net/ttv-boxart/492546-{width}x{height}.jpg
# 28           https://static-cdn.jtvnw.net/ttv-boxart/138585-{width}x{height}.jpg
# 29      https://static-cdn.jtvnw.net/ttv-boxart/491931_IGDB-{width}x{height}.jpg
# 30           https://static-cdn.jtvnw.net/ttv-boxart/509660-{width}x{height}.jpg
# 31      https://static-cdn.jtvnw.net/ttv-boxart/512953_IGDB-{width}x{height}.jpg
# 32       https://static-cdn.jtvnw.net/ttv-boxart/1669431183-{width}x{height}.jpg
# 33           https://static-cdn.jtvnw.net/ttv-boxart/518203-{width}x{height}.jpg
# 34            https://static-cdn.jtvnw.net/ttv-boxart/13389-{width}x{height}.jpg
# 35  https://static-cdn.jtvnw.net/ttv-boxart/1804231074_IGDB-{width}x{height}.jpg
# 36   https://static-cdn.jtvnw.net/ttv-boxart/401587136_IGDB-{width}x{height}.jpg
# 37      https://static-cdn.jtvnw.net/ttv-boxart/263490_IGDB-{width}x{height}.jpg
# 38           https://static-cdn.jtvnw.net/ttv-boxart/460630-{width}x{height}.jpg
# 39      https://static-cdn.jtvnw.net/ttv-boxart/513181_IGDB-{width}x{height}.jpg
# 40       https://static-cdn.jtvnw.net/ttv-boxart/29452_IGDB-{width}x{height}.jpg
# 41           https://static-cdn.jtvnw.net/ttv-boxart/498566-{width}x{height}.jpg
# 42           https://static-cdn.jtvnw.net/ttv-boxart/417752-{width}x{height}.jpg
# 43       https://static-cdn.jtvnw.net/ttv-boxart/65632_IGDB-{width}x{height}.jpg
# 44      https://static-cdn.jtvnw.net/ttv-boxart/493959_IGDB-{width}x{height}.jpg
# 45  https://static-cdn.jtvnw.net/ttv-boxart/2058566581_IGDB-{width}x{height}.jpg
# 46   https://static-cdn.jtvnw.net/ttv-boxart/987413865_IGDB-{width}x{height}.jpg
# 47      https://static-cdn.jtvnw.net/ttv-boxart/508455_IGDB-{width}x{height}.jpg
# 48           https://static-cdn.jtvnw.net/ttv-boxart/497057-{width}x{height}.jpg
# 49  https://static-cdn.jtvnw.net/ttv-boxart/1106985046_IGDB-{width}x{height}.jpg
# 50           https://static-cdn.jtvnw.net/ttv-boxart/490377-{width}x{height}.jpg
# 51      https://static-cdn.jtvnw.net/ttv-boxart/508685_IGDB-{width}x{height}.jpg
# 52      https://static-cdn.jtvnw.net/ttv-boxart/515586_IGDB-{width}x{height}.jpg
# 53      https://static-cdn.jtvnw.net/ttv-boxart/459931_IGDB-{width}x{height}.jpg
# 54           https://static-cdn.jtvnw.net/ttv-boxart/488190-{width}x{height}.jpg
# 55           https://static-cdn.jtvnw.net/ttv-boxart/509659-{width}x{height}.jpg
# 56            https://static-cdn.jtvnw.net/ttv-boxart/30921-{width}x{height}.jpg
# 57  https://static-cdn.jtvnw.net/ttv-boxart/1801167658_IGDB-{width}x{height}.jpg
# 58  https://static-cdn.jtvnw.net/ttv-boxart/1756782008_IGDB-{width}x{height}.jpg
# 59   https://static-cdn.jtvnw.net/ttv-boxart/329951934_IGDB-{width}x{height}.jpg
# 60           https://static-cdn.jtvnw.net/ttv-boxart/499973-{width}x{height}.jpg
# 61       https://static-cdn.jtvnw.net/ttv-boxart/19619_IGDB-{width}x{height}.jpg
# 62      https://static-cdn.jtvnw.net/ttv-boxart/417528_IGDB-{width}x{height}.jpg
# 63    https://static-cdn.jtvnw.net/ttv-boxart/55453844_IGDB-{width}x{height}.jpg
# 64       https://static-cdn.jtvnw.net/ttv-boxart/12839_IGDB-{width}x{height}.jpg
# 65  https://static-cdn.jtvnw.net/ttv-boxart/2106425216_IGDB-{width}x{height}.jpg
# 66       https://static-cdn.jtvnw.net/ttv-boxart/71375_IGDB-{width}x{height}.jpg
# 67       https://static-cdn.jtvnw.net/ttv-boxart/1307200028-{width}x{height}.jpg
# 68            https://static-cdn.jtvnw.net/ttv-boxart/26936-{width}x{height}.jpg
# 69           https://static-cdn.jtvnw.net/ttv-boxart/515024-{width}x{height}.jpg
# 70   https://static-cdn.jtvnw.net/ttv-boxart/687129551_IGDB-{width}x{height}.jpg
# 71      https://static-cdn.jtvnw.net/ttv-boxart/505705_IGDB-{width}x{height}.jpg
# 72      https://static-cdn.jtvnw.net/ttv-boxart/386821_IGDB-{width}x{height}.jpg
# 73            https://static-cdn.jtvnw.net/ttv-boxart/27284-{width}x{height}.jpg
# 74      https://static-cdn.jtvnw.net/ttv-boxart/491168_IGDB-{width}x{height}.jpg
# 75   https://static-cdn.jtvnw.net/ttv-boxart/409950050_IGDB-{width}x{height}.jpg
# 76  https://static-cdn.jtvnw.net/ttv-boxart/1282866981_IGDB-{width}x{height}.jpg
# 77        https://static-cdn.jtvnw.net/ttv-boxart/1229_IGDB-{width}x{height}.jpg
# 78       https://static-cdn.jtvnw.net/ttv-boxart/23020_IGDB-{width}x{height}.jpg
# 79   https://static-cdn.jtvnw.net/ttv-boxart/504371622_IGDB-{width}x{height}.jpg
# 80       https://static-cdn.jtvnw.net/ttv-boxart/1672324422-{width}x{height}.jpg
# 81        https://static-cdn.jtvnw.net/ttv-boxart/272263131-{width}x{height}.jpg
# 82   https://static-cdn.jtvnw.net/ttv-boxart/569438345_IGDB-{width}x{height}.jpg
# 83            https://static-cdn.jtvnw.net/ttv-boxart/13332-{width}x{height}.jpg
# 84        https://static-cdn.jtvnw.net/ttv-boxart/670867987-{width}x{height}.jpg
# 85      https://static-cdn.jtvnw.net/ttv-boxart/494184_IGDB-{width}x{height}.jpg
# 86   https://static-cdn.jtvnw.net/ttv-boxart/209738946_IGDB-{width}x{height}.jpg
# 87  https://static-cdn.jtvnw.net/ttv-boxart/2013539540_IGDB-{width}x{height}.jpg
# 88   https://static-cdn.jtvnw.net/ttv-boxart/538054672_IGDB-{width}x{height}.jpg
# 89      https://static-cdn.jtvnw.net/ttv-boxart/512998_IGDB-{width}x{height}.jpg
# 90  https://static-cdn.jtvnw.net/ttv-boxart/1549167076_IGDB-{width}x{height}.jpg
# 91  https://static-cdn.jtvnw.net/ttv-boxart/1294658629_IGDB-{width}x{height}.jpg
# 92             https://static-cdn.jtvnw.net/ttv-boxart/2748-{width}x{height}.jpg
# 93  https://static-cdn.jtvnw.net/ttv-boxart/2068583461_IGDB-{width}x{height}.jpg
# 94  https://static-cdn.jtvnw.net/ttv-boxart/1023750977_IGDB-{width}x{height}.jpg
# 95        https://static-cdn.jtvnw.net/ttv-boxart/1041_IGDB-{width}x{height}.jpg
# 96        https://static-cdn.jtvnw.net/ttv-boxart/1494_IGDB-{width}x{height}.jpg
# 97      https://static-cdn.jtvnw.net/ttv-boxart/510389_IGDB-{width}x{height}.jpg
# 98           https://static-cdn.jtvnw.net/ttv-boxart/499634-{width}x{height}.jpg
# 99       https://static-cdn.jtvnw.net/ttv-boxart/32502_IGDB-{width}x{height}.jpg
#
#    igdb_id  total_viewers  num_streams   avg_viewers  \
# 0                  214928           19  11312.000000
# 1     1020          52329           19   2754.157895
# 2                  117216           20   5860.800000
# 3    18866          67164           20   3358.200000
# 4      115          56480           20   2824.000000
# 5                   45056           19   2371.368421
# 6                   80967           19   4261.421053
# 7   126459          48300           20   2415.000000
# 8     1905          40083           20   2004.150000
# 9   131800          36776           20   1838.800000
# 10  308698          42629           19   2243.631579
# 11     123          23323           20   1166.150000
# 12  135400          28407           18   1578.166667
# 13                  29118           20   1455.900000
# 14   90099          25329           20   1266.450000
# 15   27789          25393           19   1336.473684
# 16  294041          21986           20   1099.300000
# 17  324720          29862            7   4266.000000
# 18  137989          29224           20   1461.200000
# 19  336964          23716           19   1248.210526
# 20  114795          15621           20    781.050000
# 21  125174          21570           20   1078.500000
# 22  305152          11930           20    596.500000
# 23                  18842           18   1046.777778
# 24     386          13287           20    664.350000
# 25  120176          16070           20    803.500000
# 26    1184          16576           20    828.800000
# 27   26401          17658           20    882.900000
# 28    1279          14924           20    746.200000
# 29   15536          12837           20    641.850000
# 30                   4537           20    226.850000
# 31  119133           9773           20    488.650000
# 32                   8664           20    433.200000
# 33                  10935           20    546.750000
# 34                  11638           20    581.900000
# 35  215955           9515           20    475.750000
# 36  298915           9686           20    484.300000
# 37    3277           7352           19    386.947368
# 38    7360           7683           20    384.150000
# 39  119277           5998           19    315.684211
# 40   45517          10194           18    566.333333
# 41                   7454           19    392.315789
# 42                   8382           20    419.100000
# 43    2117           8268           20    413.400000
# 44   25076           6391           20    319.550000
# 45  134071           9825           19    517.105263
# 46  314090           9811            3   3270.333333
# 47  104967           9257           20    462.850000
# 48   25657           7806           20    390.300000
# 49  314239           7945           19    418.157895
# 50   11137           7980           20    399.000000
# 51  103244           8866            6   1477.666667
# 52  127697           7551           20    377.550000
# 53   79824           7269           20    363.450000
# 54                   7147           20    357.350000
# 55                   6182           20    309.100000
# 56   11198           5100           20    255.000000
# 57  290959           7758           20    387.900000
# 58  288741           7769           20    388.450000
# 59  182241           7616           20    380.800000
# 60                   4872           20    243.600000
# 61    9596           4016           20    200.800000
# 62   19698           5683           20    284.150000
# 63  191692           6515           20    325.750000
# 64     364           6945           20    347.250000
# 65  275070           5440           20    272.000000
# 66    1595           4971           20    248.550000
# 67                   6020           20    301.000000
# 68                   3206           19    168.736842
# 69  125165           6360           20    318.000000
# 70  133807           6425           20    321.250000
# 71   52006           6505           20    325.250000
# 72    6292           4439           20    221.950000
# 73                   3072           19    161.684211
# 74   15707           5787           19    304.578947
# 75  159685           5484            1   5484.000000
# 76  262186           3805           20    190.250000
# 77    1070           5363           20    268.150000
# 78   17269           1927           19    101.421053
# 79  332273           5254           20    262.700000
# 80  302156           3292           20    164.600000
# 81                   3816           19    200.842105
# 82  342760           3829           18    212.722222
# 83                   4516           20    225.800000
# 84                   4242           20    212.100000
# 85   79392           4017           20    200.850000
# 86  202956           3694           20    184.700000
# 87  149657           4119           20    205.950000
# 88  217590           4138           20    206.900000
# 89  119388           4598           20    229.900000
# 90  126153           4575           19    240.789474
# 91  332780           1734           19     91.263158
# 92                   3984           20    199.200000
# 93  308034           2292           17    134.823529
# 94  305155           3341           20    167.050000
# 95     126           3838           20    191.900000
# 96     621            523           20     26.150000
# 97   18090           4000           10    400.000000
# 98   76760           3180           20    159.000000
# 99    5587           3522           20    176.100000
#
#                                                                                      languages  \
# 0                              {"es": 2, "fr": 1, "ru": 6, "en": 6, "de": 2, "pl": 1, "ja": 1}
# 1                                       {"zh": 1, "en": 7, "de": 3, "ja": 6, "th": 1, "sv": 1}
# 2                                       {"ru": 9, "en": 6, "pt": 2, "uk": 1, "th": 1, "tl": 1}
# 3                                      {"en": 12, "ru": 2, "es": 1, "pt": 2, "de": 2, "fr": 1}
# 4            {"fr": 4, "ja": 1, "en": 8, "de": 1, "cs": 1, "it": 1, "es": 2, "pt": 1, "da": 1}
# 5                              {"ru": 5, "en": 6, "pt": 2, "de": 2, "pl": 2, "uk": 1, "es": 1}
# 6                     {"de": 8, "en": 4, "es": 1, "da": 1, "ru": 1, "fr": 1, "cs": 2, "pl": 1}
# 7                              {"es": 7, "pt": 1, "en": 4, "fr": 2, "zh": 4, "ru": 1, "ja": 1}
# 8         {"en": 7, "fr": 4, "de": 1, "es": 1, "ru": 2, "it": 2, "nl": 1, "pl": 1, "other": 1}
# 9                                               {"en": 12, "fr": 2, "it": 3, "de": 2, "es": 1}
# 10  {"en": 6, "de": 3, "es": 2, "fr": 2, "pt": 1, "it": 1, "ru": 1, "pl": 1, "ja": 1, "ar": 1}
# 11                                              {"en": 13, "de": 4, "ru": 1, "fr": 1, "es": 1}
# 12                                               {"fr": 5, "ru": 4, "en": 6, "cs": 1, "ja": 2}
# 13                                              {"es": 4, "en": 11, "fr": 3, "de": 1, "ru": 1}
# 14                                              {"es": 1, "de": 2, "en": 14, "it": 1, "fr": 2}
# 15                    {"ru": 5, "en": 8, "th": 1, "zh": 1, "pt": 1, "de": 1, "fr": 1, "hu": 1}
# 16                                                                {"en": 18, "ru": 1, "ar": 1}
# 17                                                                 {"de": 2, "en": 3, "fr": 2}
# 18          {"es": 10, "en": 2, "ro": 1, "ru": 2, "zh": 1, "ja": 1, "it": 1, "fr": 1, "ar": 1}
# 19                             {"de": 4, "en": 6, "es": 3, "hu": 1, "it": 2, "pt": 2, "fr": 1}
# 20                                               {"en": 9, "zh": 3, "ru": 2, "ja": 4, "fr": 2}
# 21                                     {"ja": 6, "en": 10, "es": 1, "fr": 1, "ru": 1, "pt": 1}
# 22                                           {"en": 12, "de": 1, "zh-hk": 1, "fr": 5, "el": 1}
# 23                             {"en": 6, "fr": 2, "it": 2, "es": 1, "de": 4, "pt": 1, "ru": 2}
# 24                                              {"fr": 1, "en": 12, "ja": 5, "ru": 1, "de": 1}
# 25                    {"en": 9, "es": 2, "fr": 1, "pl": 1, "pt": 4, "ja": 1, "zh": 1, "hu": 1}
# 26                             {"en": 5, "de": 4, "ru": 2, "pl": 4, "hu": 3, "cs": 1, "es": 1}
# 27                                              {"en": 14, "fr": 3, "de": 1, "ja": 1, "ru": 1}
# 28                             {"en": 6, "zh": 3, "ru": 6, "fr": 2, "ja": 1, "es": 1, "uk": 1}
# 29                                     {"en": 10, "ru": 5, "ja": 1, "fr": 1, "de": 2, "sv": 1}
# 30                                                                {"en": 18, "es": 1, "de": 1}
# 31                   {"en": 10, "uk": 1, "ru": 1, "de": 3, "fr": 2, "it": 1, "es": 1, "ja": 1}
# 32                                                                {"en": 12, "de": 7, "pt": 1}
# 33                                      {"es": 8, "it": 5, "en": 3, "de": 2, "pt": 1, "ca": 1}
# 34                             {"en": 6, "ru": 2, "fr": 2, "es": 5, "de": 2, "zh": 1, "pt": 2}
# 35                                                                                  {"zh": 20}
# 36                                     {"ru": 11, "en": 5, "pt": 1, "pl": 1, "es": 1, "de": 1}
# 37                                     {"en": 10, "es": 3, "pt": 2, "ru": 2, "pl": 1, "de": 1}
# 38                                     {"en": 12, "pt": 2, "fr": 2, "ja": 1, "es": 1, "de": 2}
# 39                             {"ru": 5, "en": 5, "ar": 2, "fr": 4, "it": 1, "es": 1, "pl": 1}
# 40                                                       {"pt": 13, "ru": 3, "uk": 1, "en": 1}
# 41        {"pl": 1, "en": 7, "da": 2, "el": 3, "other": 1, "pt": 1, "es": 2, "de": 1, "sv": 1}
# 42                                                                {"es": 9, "en": 10, "fr": 1}
# 43                                     {"en": 10, "fr": 2, "ru": 2, "pl": 1, "de": 2, "es": 3}
# 44                   {"de": 10, "fi": 1, "pt": 2, "cs": 1, "th": 2, "en": 1, "el": 1, "fr": 2}
# 45                    {"ru": 3, "es": 2, "en": 5, "sk": 2, "uk": 3, "de": 1, "pl": 1, "pt": 2}
# 46                                                                                   {"de": 3}
# 47                                               {"en": 6, "ru": 8, "de": 4, "pt": 1, "ja": 1}
# 48                                                       {"en": 17, "es": 1, "fr": 1, "pt": 1}
# 49                 {"ru": 2, "en": 3, "other": 1, "de": 6, "hu": 1, "pt": 1, "fr": 3, "es": 2}
# 50                                               {"en": 9, "fr": 4, "ru": 2, "de": 4, "pl": 1}
# 51                                                                 {"en": 2, "ru": 3, "de": 1}
# 52                             {"en": 6, "fr": 2, "ru": 6, "de": 3, "cs": 1, "pl": 1, "zh": 1}
# 53                                                                                  {"en": 20}
# 54                                                                {"en": 14, "pt": 5, "es": 1}
# 55                                                                {"ja": 1, "en": 18, "es": 1}
# 56                             {"fr": 5, "es": 1, "en": 9, "ar": 2, "pt": 1, "el": 1, "de": 1}
# 57                                           {"de": 10, "en": 6, "fr": 2, "ru": 1, "other": 1}
# 58                                                       {"en": 8, "de": 10, "ja": 1, "ru": 1}
# 59                                                       {"es": 8, "en": 10, "pt": 1, "fr": 1}
# 60                                                       {"en": 15, "de": 2, "ja": 1, "es": 2}
# 61                                                                {"pl": 4, "pt": 13, "en": 3}
# 62                                               {"es": 4, "en": 8, "pt": 4, "ru": 3, "pl": 1}
# 63                                                        {"ja": 9, "en": 9, "fr": 1, "ru": 1}
# 64                                                       {"ru": 13, "pl": 3, "uk": 2, "en": 2}
# 65                                              {"en": 15, "fr": 2, "pt": 1, "de": 1, "pl": 1}
# 66                                      {"de": 7, "es": 2, "en": 4, "fr": 3, "ru": 1, "cs": 3}
# 67                                                                                  {"en": 20}
# 68                                              {"ru": 2, "en": 14, "zh": 1, "ja": 1, "pt": 1}
# 69                            {"en": 10, "de": 3, "es": 3, "pt": 1, "pl": 1, "fr": 1, "ja": 1}
# 70                                                                {"en": 14, "fr": 4, "de": 2}
# 71                            {"en": 10, "ja": 3, "ru": 3, "de": 1, "it": 1, "pt": 1, "fr": 1}
# 72                             {"en": 7, "zh": 2, "de": 1, "ru": 3, "pt": 5, "ja": 1, "th": 1}
# 73                                                       {"en": 15, "ru": 1, "fr": 2, "de": 1}
# 74                                      {"ru": 6, "de": 5, "es": 1, "en": 4, "fr": 1, "it": 2}
# 75                                                                                   {"ru": 1}
# 76                    {"ru": 6, "en": 6, "de": 2, "es": 2, "pt": 1, "tr": 1, "fr": 1, "th": 1}
# 77                                                                         {"en": 15, "de": 5}
# 78                                                       {"en": 11, "pt": 3, "ru": 3, "es": 2}
# 79                                              {"zh": 3, "en": 12, "de": 3, "ru": 1, "fr": 1}
# 80                                                                {"en": 12, "ar": 7, "fr": 1}
# 81                                                       {"en": 16, "zh": 1, "ja": 1, "de": 1}
# 82                             {"ru": 3, "hu": 2, "en": 7, "pt": 1, "de": 3, "sk": 1, "it": 1}
# 83                                              {"it": 3, "en": 13, "fr": 1, "de": 2, "es": 1}
# 84                                     {"en": 11, "zh": 1, "it": 1, "fr": 2, "de": 3, "es": 2}
# 85                                                                         {"ru": 19, "es": 1}
# 86           {"es": 3, "en": 6, "ru": 4, "pt": 1, "zh": 1, "de": 2, "ar": 1, "pl": 1, "fr": 1}
# 87                            {"en": 12, "it": 3, "fr": 1, "hu": 1, "el": 1, "pt": 1, "ar": 1}
# 88                                                       {"en": 13, "ru": 5, "fr": 1, "de": 1}
# 89                                      {"en": 9, "ja": 3, "fr": 2, "de": 2, "es": 3, "ru": 1}
# 90                                                                {"ru": 12, "en": 5, "uk": 2}
# 91                                      {"en": 9, "de": 4, "pt": 1, "ru": 3, "ja": 1, "pl": 1}
# 92                                     {"en": 15, "pt": 1, "de": 1, "es": 1, "it": 1, "pl": 1}
# 93                                                                {"en": 15, "pt": 1, "es": 1}
# 94                                      {"pt": 3, "ru": 6, "zh": 2, "en": 6, "de": 2, "ja": 1}
# 95                                                       {"en": 12, "pl": 4, "ru": 3, "bg": 1}
# 96                                              {"es": 4, "en": 11, "ru": 1, "pt": 3, "fr": 1}
# 97                                      {"de": 5, "hu": 1, "cs": 1, "pl": 1, "fr": 1, "en": 1}
# 98                                              {"en": 10, "es": 1, "fr": 4, "pt": 3, "ru": 2}
# 99                             {"fr": 3, "en": 7, "de": 3, "es": 1, "pl": 4, "ja": 1, "zh": 1}
#
#     has_mature_stream
# 0                True
# 1                True
# 2                True
# 3                True
# 4                True
# 5                True
# 6                True
# 7                True
# 8               False
# 9                True
# 10               True
# 11               True
# 12               True
# 13               True
# 14               True
# 15               True
# 16               True
# 17               True
# 18               True
# 19               True
# 20               True
# 21              False
# 22               True
# 23              False
# 24               True
# 25               True
# 26               True
# 27               True
# 28               True
# 29               True
# 30               True
# 31               True
# 32               True
# 33               True
# 34               True
# 35               True
# 36               True
# 37               True
# 38               True
# 39               True
# 40               True
# 41               True
# 42               True
# 43               True
# 44               True
# 45               True
# 46               True
# 47               True
# 48               True
# 49               True
# 50               True
# 51               True
# 52               True
# 53               True
# 54               True
# 55               True
# 56               True
# 57               True
# 58               True
# 59               True
# 60               True
# 61               True
# 62               True
# 63               True
# 64               True
# 65               True
# 66               True
# 67               True
# 68               True
# 69               True
# 70               True
# 71               True
# 72               True
# 73               True
# 74              False
# 75              False
# 76               True
# 77               True
# 78              False
# 79               True
# 80               True
# 81               True
# 82               True
# 83               True
# 84               True
# 85              False
# 86               True
# 87               True
# 88               True
# 89               True
# 90               True
# 91               True
# 92               True
# 93               True
# 94               True
# 95               True
# 96               True
# 97               True
# 98               True
# 99               True

# %%
# Guardar en parquet
df_twitch_spark = spark.createDataFrame(df_twitch_enriched)
archivo_twitch = "twitch_top_games.parquet"
df_twitch_spark.write.mode("overwrite").parquet(f"/home/jovyan/work/{archivo_twitch}")

# Log
fin = datetime.now()
insertar_log_mysql("Twitch", archivo_twitch, df_twitch_enriched.shape[0], inicio, fin)

# %% [markdown]
# **Descarga desde HowLongToBeat API (no oficial)**

# %%
from datetime import datetime
from howlongtobeatpy import HowLongToBeat
import pandas as pd
import json

# Inicio del proceso
inicio = datetime.now()

# Lista amplia de títulos conocidos
titulos = [
    "Zelda", "Elden Ring", "Dark Souls", "Sekiro", "Bloodborne",
    "Final Fantasy", "Persona", "The Witcher", "Cyberpunk", "Hollow Knight",
    "God of War", "Red Dead", "GTA", "Call of Duty", "Fortnite",
    "League of Legends", "Valorant", "Overwatch", "Apex Legends", "CSGO",
    "Pokémon", "Metroid", "Mario", "Luigi", "Donkey Kong",
    "Kirby", "Fire Emblem", "Xenoblade", "Dragon Quest", "Monster Hunter",
    "Resident Evil", "Silent Hill", "Assassin’s Creed", "Far Cry", "Watch Dogs",
    "Minecraft", "Terraria", "Starfield", "Baldur’s Gate", "Star Wars",
    "Bayonetta", "Cuphead", "Celeste", "Dead Cells", "Stardew Valley",
    "Slay the Spire", "Hades", "Returnal", "Deathloop", "It Takes Two",
    "The Last of Us", "Uncharted", "Ratchet & Clank", "Spyro", "Crash Bandicoot",
    "Titanfall", "Borderlands", "BioShock", "Fallout", "Skyrim",
    "Oblivion", "Morrowind", "Doom", "Quake", "Halo",
    "Destiny", "Battlefield", "PUBG", "The Division", "Splatoon",
    "Firewatch", "Oxenfree", "Undertale", "Inside", "Limbo",
    "Valheim", "Grounded", "Satisfactory", "The Forest", "No Man’s Sky",
    "Ark", "Subnautica", "Dying Light", "Dead Island", "The Evil Within",
    "Alan Wake", "Control", "The Sims", "SimCity", "Cities Skylines",
    "RollerCoaster Tycoon", "FIFA", "NBA 2K", "Madden", "Gran Turismo",
    "Forza", "Need for Speed", "Tetris", "Pac-Man", "Street Fighter"
]
# Buscar resultados
hltb = HowLongToBeat()
resultados = []

for i, titulo in enumerate(titulos, 1):
    resultados += hltb.search(titulo)

    
datos_raw = [{"raw_json": json.dumps(r.__dict__)} for r in resultados]
# Crear DataFrame pandas y pasarlo a Spark
df_hltb = pd.DataFrame(datos_raw)

if df_hltb.empty:
    print("⚠️ No se obtuvieron resultados. El DataFrame está vacío.")
else:
    df_hltb_spark = spark.createDataFrame(df_hltb)

# Guardar como Parquet
archivo_hltb = "howlongtobeat_multiple_raw.parquet"
df_hltb_spark.write.mode("overwrite").parquet(f"/home/jovyan/work/{archivo_hltb}")

# Registrar en log
fin = datetime.now()
insertar_log_mysql("HowLongToBeat", archivo_hltb, df_hltb.shape[0], inicio, fin)

print("Fase 1 completada: HowLongToBeat guardado como raw_json")

# %% [markdown]
# **Datos desde Pokémon Showdown (GitHub)**

# %%
from datetime import datetime
import requests
import pandas as pd

# Inicio del proceso
inicio = datetime.now()

# URL oficial del archivo Pokedex
url = "https://raw.githubusercontent.com/smogon/pokemon-showdown/master/data/pokedex.ts"

# Descargar el archivo completo como texto
response = requests.get(url)
data_text = response.text

# Extraer solo el bloque de la pokédex (entre llaves)
start = data_text.find("{")  # Primera llave
end = data_text.rfind("}")   # Última llave
bloque_raw = data_text[start:end+1]  # Incluir la última llave

# Guardar como raw_json (una fila con la pokedex completa)
df_showdown = pd.DataFrame([{"raw_json": bloque_raw}])
df_showdown_spark = spark.createDataFrame(df_showdown)

# Nombre del archivo
archivo_showdown = "pokemon_showdown_pokedex_raw.parquet"

# Guardar como Parquet
df_showdown_spark.write.mode("overwrite").parquet(f"/home/jovyan/work/{archivo_showdown}")

# Fin y registro en log
fin = datetime.now()
# insertar_log_mysql("Pokemon Showdown", archivo_showdown, 1, inicio, fin)

print("Fase 1 completada: Pokédex guardada como raw_json")
# Out:
# Fase 1 completada: Pokédex guardada como raw_json
